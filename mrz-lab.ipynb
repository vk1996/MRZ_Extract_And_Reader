# %%
import cv2 as cv
from nbutil import show_image

# %% [markdown]
# Where is the MRZ? The angle brackets will show you the way 💪
# ======================================================================================
#
# The task is to locate on any photo the angle brackets <<< that are typically used as empty characters in MRZ.
#
# Starting with an image like this:

# %%
show_image(cv.imread('sample2.jpg'))

# %% [markdown]
# The first half of the challenge is to develop a model that can find the <<< brackets on the image. The model input should be the raw photo and the output should be then:
# * either a segmentation mask, like in the image below,
# * or the regressed coordinates of the brackets.
#
# Use an ANN package of your choice, preferably Tensorflow or Keras, for developing the model. You'll notice that there is no training dataset for the model - you'll need to develop the dataset as well. A synthetic dataset should be good enough for this task.
#
# For bonus points, try to come up with a cheap and efficient architecture that is appropriate for the complexity of the task. For example, can you justify using a model with millions of parameters here?

# %%
show_image(cv.imread('highlighted.jpg'))

# %% [markdown]
# If your model outputs a segmentation mask, you can then use plain OpenCV to recover the coordinates of the <<< symbols from the image.
#
# Having the coordinates of the <<< symbols, the second half of the challenge is to recover the area of each MRZ line from those coordinates. Develop an algorithmic solution for this part.
#
# For bonus points, develop an efficient solution. For example, avoid performing operations on the full input image and use localized crops of the region of interest instead.

# %%
show_image(cv.imread('mrz-outline.jpg'))

# %% [markdown]
# Your mission, should you choose to accept it, is to develop a solution that can get from the first image to the last image for any photo of a travel/identity document that is reasonably well lit and aligned on the image. Basically, any photo with a modern smartphone of a travel document.
#
# Clone this repo and develop your solutions here. Add comments to the code explaining what it is that you're trying to achieve or explore.
#
# We'd like to give feedback often and discuss your efforts as they unfold. We'll be glad to help immediately with any stumbling blocks that you might encounter on the way, so push your code often. There's no point in getting stuck in technical details with which we might already have experience. The flow of the task should feel like actual teamwork.
#
# Don't worry, the challenge is not timed. It's fine if you need to pause the work on the challenge for some time. Just give us a heads up.
#
# Good luck and have fun!

# %% [markdown]
# **NOTE: you can use your own identity document for testing, but be sure to clear all outputs before committing!**
